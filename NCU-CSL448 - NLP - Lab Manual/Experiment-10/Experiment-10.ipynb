# %% [markdown]
# # **Experiment-10**

# %% [markdown]
# ### Objective:
# Write a program to read text data from a file and implement Named Entity Recognition.

# %%
# %pip install spacy pandas
# !python -m spacy download en_core_web_sm
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------- ------------------------------ 2.9/12.8 MB 18.6 MB/s eta 0:00:01
#      ------------------ --------------------- 6.0/12.8 MB 19.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.4/12.8 MB 16.3 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 16.7 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy
import pandas as pd

# %%
def read_text_file(file_path):
    """Read text data from the file."""
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

# Read text from 'input.txt'
file_path = 'input.txt'
text = read_text_file(file_path)
print(text)
# Out:
# Microsoft announced a new product launch event in New York City on December 1st, 2024.
# Elon Musk, the CEO of Tesla, hinted at a partnership with NASA for a Mars mission.
# The GDP of India grew by 7% in the first quarter of 2023, according to a report by Reuters.
# Amazon is planning to open a new data center in Dublin, Ireland next year.
# Barack Obama gave a keynote speech at Stanford University last Thursday.
# Bitcoin reached an all-time high of $68,000 in November 2021.
# The Louvre Museum in Paris saw record-breaking attendance last summer.

# %%
def perform_ner(text):
    """Perform Named Entity Recognition using spaCy."""
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    
    # Extract entities and their labels
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    
    return entities

# Perform NER on the text
entities = perform_ner(text)
entities
# Out:
# [('Microsoft', 'ORG'),
#  ('New York City', 'GPE'),
#  ('December 1st, 2024', 'DATE'),
#  ('Elon Musk', 'PERSON'),
#  ('Tesla', 'ORG'),
#  ('NASA', 'ORG'),
#  ('Mars', 'LOC'),
#  ('India', 'GPE'),
#  ('7%', 'PERCENT'),
#  ('the first quarter of 2023', 'DATE'),
#  ('Reuters', 'ORG'),
#  ('Amazon', 'ORG'),
#  ('Dublin', 'GPE'),
#  ('Ireland', 'GPE'),
#  ('next year', 'DATE'),
#  ('Barack Obama', 'PERSON'),
#  ('Stanford University', 'ORG'),
#  ('last Thursday', 'DATE'),
#  ('Bitcoin', 'PERSON'),
#  ('68,000', 'MONEY'),
#  ('November 2021', 'DATE'),
#  ('The Louvre Museum', 'ORG'),
#  ('Paris', 'GPE'),
#  ('last summer', 'DATE')]

# %%
df_entities = pd.DataFrame(entities, columns=["Entity", "Label"])
df_entities
# Out:
#                        Entity    Label
# 0                   Microsoft      ORG
# 1               New York City      GPE
# 2          December 1st, 2024     DATE
# 3                   Elon Musk   PERSON
# 4                       Tesla      ORG
# 5                        NASA      ORG
# 6                        Mars      LOC
# 7                       India      GPE
# 8                          7%  PERCENT
# 9   the first quarter of 2023     DATE
# 10                    Reuters      ORG
# 11                     Amazon      ORG
# 12                     Dublin      GPE
# 13                    Ireland      GPE
# 14                  next year     DATE
# 15               Barack Obama   PERSON
# 16        Stanford University      ORG
# 17              last Thursday     DATE
# 18                    Bitcoin   PERSON
# 19                     68,000    MONEY
# 20              November 2021     DATE
# 21          The Louvre Museum      ORG
# 22                      Paris      GPE
# ...

# %%
label_descriptions = {
    "PERSON": "People, including fictional characters",
    "ORG": "Organizations (e.g., companies, non-profits)",
    "GPE": "Geopolitical entities (e.g., countries, cities)",
    "DATE": "Dates or periods",
    "TIME": "Times smaller than a day",
    "MONEY": "Monetary values",
    "LOC": "Non-GPE locations (e.g., mountains, rivers)",
    "PRODUCT": "Objects, vehicles, foods, etc.",
    "EVENT": "Named events (e.g., hurricanes, wars)",
    "WORK_OF_ART": "Titles of books, songs, etc.",
    "LAW": "Named documents (e.g., treaties, laws)",
    "LANGUAGE": "Any named language",
}

# Display the label descriptions
pd.DataFrame(label_descriptions.items(), columns=["Label", "Description"])
# Out:
#           Label                                      Description
# 0        PERSON           People, including fictional characters
# 1           ORG     Organizations (e.g., companies, non-profits)
# 2           GPE  Geopolitical entities (e.g., countries, cities)
# 3          DATE                                 Dates or periods
# 4          TIME                         Times smaller than a day
# 5         MONEY                                  Monetary values
# 6           LOC      Non-GPE locations (e.g., mountains, rivers)
# 7       PRODUCT                   Objects, vehicles, foods, etc.
# 8         EVENT            Named events (e.g., hurricanes, wars)
# 9   WORK_OF_ART                     Titles of books, songs, etc.
# 10          LAW           Named documents (e.g., treaties, laws)
# 11     LANGUAGE                               Any named language
