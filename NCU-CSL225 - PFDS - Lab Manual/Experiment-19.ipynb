# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Import csv, excel, html etc using Pandas and also convert dictionary to dataframe etc.

# %%
import pandas as pd

# %% [markdown]
# Reading Data from CSV Files in Python with Pandas

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# Reading excel files in python with pandas

# %%
import pandas as pd
df = pd.read_excel('heart.xlsx')
print(df)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope
# 0    52    1   0       125   212    0        1      168      0      1.0      2
# 1    53    1   0       140   203    1        0      155      1      3.1      0
# 2    70    1   0       145   174    0        1      125      1      2.6      0
# 3    61    1   0       148   203    0        1      161      0      0.0      2
# 4    62    0   0       138   294    1        1      106      0      1.9      1
# 5    58    0   0       100   248    0        0      122      0      1.0      1
# 6    58    1   0       114   318    0        2      140      0      4.4      0
# 7    55    1   0       160   289    0        0      145      1      0.8      1
# 8    46    1   0       120   249    0        0      144      0      0.8      2
# 9    54    1   0       122   286    0        0      116      1      3.2      1
# 10   71    0   0       112   149    0        1      125      0      1.6      1

# %% [markdown]
# Reading HTML content in Python with pandas

# %%
df = pd.read_html('https://trends.builtwith.com/websitelist/Responsive-Tables')
df[0]
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %% [markdown]
# Converting dictionary to Pandas DataFrame

# %%
dict = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'], 'Age':[28,34,29,42]}
df = pd.DataFrame(dict)
df
# Out:
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42
