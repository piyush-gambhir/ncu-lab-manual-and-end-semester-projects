# %% [markdown]
# ## Experiment 11
# ### Write a python program to Implement central limit theorem.

# %%
# importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Central Limit Theorem
# The central limit theorem states that if you have a population with mean μ and standard deviation σ and take sufficiently large random samples from the population with replacement , then the distribution of the sample means will be approximately normally distributed.

# %%
# implementing the central limit theorem
mu = 30
sigma = 5

samples = np.zeros(10000)

for i in range(10000):
    samples[i] = np.random.normal(mu, sigma, 10000).mean()

print("Samples mean: ", samples.mean())

sns.displot(samples, bins=30, kde=True)
# Out:
# Samples mean:  30.000085130241704
